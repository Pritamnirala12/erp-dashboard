# %% [markdown]
# <a href="https://colab.research.google.com/github/Pritamnirala12/Calculator/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
erp_data = pd.read_csv("/content/erp_dataset.csv")

# %%
np.random.seed(0)

# %%
erp_data.head()
# Out:
#      ID   Name     Role        Department  Age  Gender Joining Date  \
# 0  S001    Amy  Faculty           Biology   28  Female   2023-07-30
# 1  S002  Diana  Student             Civil   19  Female   2021-07-15
# 2  S003  Molly  Faculty         Chemistry   25  Female   2021-04-03
# 3  S004  Kevin  Student  Computer Science   28  Female   2020-06-16
# 4  S005   Yara  Student  Computer Science   48    Male   2024-02-22
#
#                  Email Phone Number       Address Attendance
# 0      bob@example.com  +1-663-8291       Phoenix    Present
# 1  charlie@example.com  +1-315-3220   Los Angeles    Present
# 2    david@example.com  +1-642-2736     San Diego    Present
# 3      eva@example.com  +1-494-9120  Philadelphia     Absent
# 4    frank@example.com  +1-178-5969       Phoenix    Present

# %%
# 1. Academic Performance Tracking - Bar Chart of Grades
erp_data['Academic Score'] = np.random.randint(50, 100, erp_data.shape[0])
plt.figure(figsize=(10, 6))
sns.histplot(erp_data['Academic Score'], bins=10, kde=True)
plt.title('Distribution of Academic Scores')
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.show()

# %%
# 2. Attendance Monitoring - Pie Chart for Attendance Status
erp_data['Attendance'] = np.random.choice(['Present', 'Absent'], erp_data.shape[0], p=[0.8, 0.2])
attendance_counts = erp_data['Attendance'].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(attendance_counts, labels=attendance_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Attendance Distribution')
plt.show()

# %%
# 3. Course Enrollment Insights - Bar Chart for Department Enrollments
plt.figure(figsize=(10, 6))
sns.countplot(data=erp_data, x='Department', hue='Role')
plt.title('Course Enrollment by Department')
plt.xlabel('Department')
plt.ylabel('Enrollment Count')
plt.xticks(rotation=45)
plt.legend(title='Role')
plt.show()

# %%
# 4. Behavior and Engagement Analysis - Scatter Plot for Age vs. Academic Score
plt.figure(figsize=(10, 6))
sns.scatterplot(data=erp_data, x='Age', y='Academic Score', hue='Gender', style='Role')
plt.title('Behavior Analysis: Age vs Academic Score')
plt.xlabel('Age')
plt.ylabel('Academic Score')
plt.show()

# %%
# 5. Fee Payment Status - Pie Chart for Fee Payment Status
erp_data['Fee Status'] = np.random.choice(['Paid', 'Unpaid', 'Partial'], erp_data.shape[0], p=[0.7, 0.2, 0.1])
fee_counts = erp_data['Fee Status'].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(fee_counts, labels=fee_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Fee Payment Status')
plt.show()

# %%
# 6. Faculty Performance and Feedback - Bar Chart for Average Faculty Ratings
erp_data['Faculty Rating'] = np.where(erp_data['Role'] == 'Faculty', np.random.uniform(3.0, 5.0, erp_data.shape[0]), np.nan)
faculty_ratings = erp_data.dropna(subset=['Faculty Rating'])
plt.figure(figsize=(10, 6))
sns.histplot(faculty_ratings['Faculty Rating'], bins=10, kde=True)
plt.title('Distribution of Faculty Ratings')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %%
# 7. Class Scheduling and Availability - Line Chart for Hypothetical Classes Scheduled Over Months
erp_data['Class Scheduled Month'] = np.random.choice(pd.date_range("2023-01-01", "2023-12-31", freq='M'), erp_data.shape[0])
monthly_schedule = erp_data.groupby(erp_data['Class Scheduled Month'].dt.month).size()
monthly_schedule.plot(kind='line', marker='o', figsize=(10, 6))
plt.title('Class Scheduling Over the Year')
plt.xlabel('Month')
plt.ylabel('Number of Classes Scheduled')
plt.show()
# Out:
# <ipython-input-12-fd62e2b1d0ff>:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   erp_data['Class Scheduled Month'] = np.random.choice(pd.date_range("2023-01-01", "2023-12-31", freq='M'), erp_data.shape[0])

# %%
# 8. Research and Publications Tracking - Bar Chart of Publications Count by Faculty
erp_data['Publications'] = np.where(erp_data['Role'] == 'Faculty', np.random.randint(0, 10, erp_data.shape[0]), 0)
faculty_publications = erp_data[erp_data['Role'] == 'Faculty']
plt.figure(figsize=(10, 6))
sns.barplot(data=faculty_publications, x='Name', y='Publications', ci=None)
plt.title('Research Publications by Faculty')
plt.xlabel('Faculty')
plt.ylabel('Number of Publications')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-13-bd57112347e5>:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=faculty_publications, x='Name', y='Publications', ci=None)

# %%
# 9. Faculty-Student Interaction Logs - Bar Chart for Interaction Frequency (mock data)
erp_data['Interactions'] = np.random.randint(5, 20, erp_data.shape[0])
plt.figure(figsize=(10, 6))
sns.histplot(erp_data['Interactions'], bins=10, kde=True)
plt.title('Faculty-Student Interactions Frequency')
plt.xlabel('Number of Interactions')
plt.ylabel('Frequency')
plt.show()

# %%
# 10. Training and Professional Development - Scatter Plot for Age vs. Training Hours
erp_data['Training Hours'] = np.random.randint(10, 50, erp_data.shape[0])
plt.figure(figsize=(10, 6))
sns.scatterplot(data=erp_data, x='Age', y='Training Hours', hue='Role', style='Gender')
plt.title('Training Hours by Age and Role')
plt.xlabel('Age')
plt.ylabel('Training Hours')
plt.show()
